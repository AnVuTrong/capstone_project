# %%
from modules.data_preprocessing import DataPreprocessing
from modules.models import ProcessModels
from modules.recommendation import Recommendation

# %%
recommendation = Recommendation(
    process_model_module=ProcessModels(DataPreprocessing(), spark=None, model_dir='models/'),
)

# %%
recommendations, user_history = recommendation.surprise_recommender(
    current_user_id='13d4a80599cf4c4f8f4c3b511e25a4d9', # By pooja s
    num_recommendations=10,
)

# %%
recommendations
# Out:
#                            CourseID  \
# 0  409f8d989f9741e496c1136833c1227a
# 1  11d4aeafdfb44ae197e30df18b37fdbd
# 2  019208b36534424daad46ca178108182
# 3  9a86f8d7de174898acf3c35600040106
# 4  1012a6fa755745488d530e6b632589ae
# 5  f83a0b870c3c457dab31f72138574c2b
# 6  aa8ddd96f08b456c9b3d1532195091ce
# 7  baeaa433af3b492db14e8c6423fc76fe
# 8  23df2c5d25944451a049a2cb6b9e1e98
# 9  9d0057791a4f4cc984cc90f9b5b7f407
#
#                                           CourseName  ReviewNumber  AvgStar  \
# 0                  Neural Networks and Deep Learning        120907      4.9
# 1                Foundations: Data, Data, Everywhere         99239      4.8
# 2  The Power of Machine Learning: Boost Business,...           145      4.8
# 3                           Introduction to Node-red            37      4.8
# 4          Structured Query Language (SQL) using SAS           252      4.9
# 5                               AI and Public Health           151      4.7
# 6      Big Data, Artificial Intelligence, and Ethics           477      4.6
# 7              Exploratory Data Analysis with MATLAB           795      4.8
# 8                               Computer Simulations            79      4.5
# 9  Linear Algebra: Orthogonality and Diagonalization            11      4.9
#
#                 Level                             Unit  \
# 0  Intermediate level                  DeepLearning.AI
# 1      Beginner level                           Google
# 2      Beginner level                              SAS
# 3      Beginner level         Coursera Project Network
# 4                 NaN                              SAS
# 5      Beginner level                  DeepLearning.AI
# 6      Beginner level  University of California, Davis
# 7      Beginner level                        MathWorks
# 8      Beginner level  University of California, Davis
# 9  Intermediate level         Johns Hopkins University
#
#                                              Results  EstimatedRating
# 0                                                NaN         4.995421
# 1  Define and explain key concepts involved in da...         4.984688
# 2  Participate in the deployment of machine learn...         4.964113
# 3  Learn to work with Node-Red Environment\nLearn...         4.923475
# 4                                                NaN         4.901048
# 5                                                NaN         4.899728
# 6  Define and discuss big data opportunities and ...         4.888741
# 7  Import large tabular datasets & customize the ...         4.876848
# 8                                                NaN         4.866206
# 9                                                NaN         4.865472

# %%
user_history
# Out:
#                            CourseID  \
# 0  b6247bd0233443ba80cd67788ead9baa
# 1  87900c57bcb44e9b9c4c04015153ddc1
# 2  c9c2325cd8c5414392bfe9586bc7fce1
# 3  c6763c020605467f95f93e8ffbd86e90
# 4  8fba60d8f2c745ea85cab0a59ccb3575
#
#                                   CourseName  ReviewNumber  AvgStar  \
# 0                      What is Data Science?         68152      4.7
# 1  Python for Data Science, AI & Development         35369      4.6
# 2                           Basic Statistics          4369      4.6
# 3  Introduction to Data Analysis Using Excel         10166      4.7
# 4  Linear Regression for Business Statistics          1335      4.8
#
#             Level                     Unit  \
# 0  Beginner level                      IBM
# 1  Beginner level                      IBM
# 2  Beginner level  University of Amsterdam
# 3             NaN          Rice University
# 4             NaN          Rice University
#
#                                              Results  RatingStar
# 0  Define data science and its importance in toda...           1
# 1  Learn Python - the most popular programming la...           4
# 2                                                NaN           5
# 3                                                NaN           5
# 4                                                NaN           5

# %%
df_reviews, df_courses = DataPreprocessing().surprise_preprocessing()
df_courses
# Out:
#                              CourseID  \
# 0    ba4c3f6733994eca9f6ce1f1926f9505
# 1    b6247bd0233443ba80cd67788ead9baa
# 2    04d627bdde99423ca09b2521631bf688
# 3    da0eb131c4064bddbae05fb64df425b8
# 4    e019840aa27444349b7019d25a1b1b8f
# ..                                ...
# 874  7f433ef7407e4ce4b3dd61df84ccf35f
# 875  d2508aba7a3e4d6983369a711342aec3
# 876  2aa79877debd49fb882de1b6cb25d300
# 877  fc8669b4bf30437ebb979f798b14b45d
# 878  20ac18144bf04e45bd70d2d3cbc69c6b
#
#                                             CourseName  \
# 0            IBM Data Science Professional Certificate
# 1                                What is Data Science?
# 2                               Data Science Challenge
# 3    Leverage Data Science for a More Agile Supply ...
# 4    Go Beyond the Numbers: Translate Data into Ins...
# ..                                                 ...
# 874                        Getting started with ImageJ
# 875                Introduction to Bayesian Statistics
# 876  Manage Data for an Online Grocer Using MySQL W...
# 877  Interpretable Machine Learning Applications: P...
# 878  Overview of Data Visualization in Microsoft Excel
#
#                                  Unit  ReviewNumber  AvgStar  \
# 0                                 IBM         69587      4.6
# 1                                 IBM         68152      4.7
# 2            Coursera Project Network             0      0.0
# 3    University of California, Irvine           184      4.5
# 4                              Google           481      4.8
# ..                                ...           ...      ...
# 874          Coursera Project Network            37      4.4
# 875                        Databricks            39      3.6
# 876          Coursera Project Network             0      0.0
# 877          Coursera Project Network             0      0.0
# 878          Coursera Project Network             0      0.0
#
#                   Level                                            Results
# 0        Beginner level  Master the most up-to-date practical skills an...
# 1        Beginner level  Define data science and its importance in toda...
# 2    Intermediate level  Load, clean, analyze, process, and visualize d...
# 3    Intermediate level  Analyze historical data to determine inventory...
# 4        Advanced level  Apply the exploratory data analysis (EDA) proc...
# ..                  ...                                                ...
# 874      Beginner level  You will learn how to use ImageJ to analyze im...
# 875      Beginner level  The basics of Probability, Bayesian statistics...
# 876  Intermediate level   Examine the current data and reorganize it in...
# 877  Intermediate level  Set up a machine learning application in a "ze...
# 878      Beginner level  Create different charts\nLearn basic principle...
#
# [879 rows x 7 columns]

# %%
from modules.helpers import generate_random_user_data
random_courses = generate_random_user_data(df_courses)
random_courses
# Out:
#                              CourseID  RatingStar
# 70   6c2645897c4a44b085d06823d2677cd4           5
# 482  6b87728edabc4c60b21e9d69993853a3           1
# 718  8accb9fef2b64091994e9e45e06fae48           4
# 235  0ffa7510c19f473281b9f3cddcbd93d1           5
# 133  0c7a2ffbfb4a426c825ab3d419ad6182           2

# %%
selected_courses = df_courses[df_courses['CourseID'].isin(random_courses['CourseID'])]
selected_courses
# Out:
#                              CourseID  \
# 70   6c2645897c4a44b085d06823d2677cd4
# 133  0c7a2ffbfb4a426c825ab3d419ad6182
# 235  0ffa7510c19f473281b9f3cddcbd93d1
# 482  6b87728edabc4c60b21e9d69993853a3
# 718  8accb9fef2b64091994e9e45e06fae48
#
#                                            CourseName  \
# 70     Generative AI: Foundation Models and Platforms
# 133                        AI for Good Specialization
# 235  Data Wrangling, Analysis and AB Testing with SQL
# 482          Managing, Describing, and Analyzing Data
# 718                                      Using ggplot
#
#                                 Unit  ReviewNumber  AvgStar  \
# 70                               IBM            62      4.8
# 133                  DeepLearning.AI           205      4.8
# 235  University of California, Davis           927      3.3
# 482   University of Colorado Boulder            27      4.6
# 718         Coursera Project Network             0      0.0
#
#                   Level                                            Results
# 70       Beginner level  Describe the fundamental concepts of generativ...
# 133      Beginner level  Master a step-by-step framework for the develo...
# 235  Intermediate level  Validate and clean a dataset\nAssess and creat...
# 482      Beginner level  Calculate descriptive statistics and create gr...
# 718      Beginner level  Install ggplot2\nLoad Tidyverse\nReview RStudi...

# %%
recommendations, user_history = recommendation.surprise_recommender(
    user_data=random_courses,
    num_recommendations=10,
    preset=False,
)
recommendations
# Out:
#                            CourseID  \
# 0  409f8d989f9741e496c1136833c1227a
# 1  11d4aeafdfb44ae197e30df18b37fdbd
# 2  8bd2b26be4aa4cf8a9c2618039f7ce3a
# 3  ad3edbdbcc84402d8c96a827978d985b
# 4  186539b1dd3e4d2585a1ac7d5c617411
# 5  a8f085ab520742769b048160a04165ba
# 6  97f50ae769134b8ba9a1a326c69b57b6
# 7  78a30f24d31f46619d85253be7284283
# 8  689d880b333b424b93733490f2b5efee
# 9  baeaa433af3b492db14e8c6423fc76fe
#
#                                           CourseName  ReviewNumber  AvgStar  \
# 0                  Neural Networks and Deep Learning        120907      4.9
# 1                Foundations: Data, Data, Everywhere         99239      4.8
# 2                  Getting started with TensorFlow 2           550      4.9
# 3                       Machine Learning: Regression          5541      4.8
# 4  Performing Data Definition and Manipulation in...           106      4.6
# 5  University Admission Prediction Using Multiple...           182      4.6
# 6  Data Analysis and Reporting in SAS Visual Anal...           349      4.8
# 7  Performing Data Aggregation using SQL Aggregat...            76      4.8
# 8                                Human Factors in AI            70      4.7
# 9              Exploratory Data Analysis with MATLAB           795      4.8
#
#                 Level                      Unit  \
# 0  Intermediate level           DeepLearning.AI
# 1      Beginner level                    Google
# 2  Intermediate level   Imperial College London
# 3                 NaN  University of Washington
# 4      Beginner level  Coursera Project Network
# 5  Intermediate level  Coursera Project Network
# 6                 NaN                       SAS
# 7  Intermediate level  Coursera Project Network
# 8      Beginner level           Duke University
# 9      Beginner level                 MathWorks
#
#                                              Results  EstimatedRating
# 0                                                NaN         4.726653
# 1  Define and explain key concepts involved in da...         4.706458
# 2                                                NaN         4.681911
# 3                                                NaN         4.667236
# 4  Learn how to use SQL data definition statement...         4.643429
# 5  Train Artificial Neural Network models to perf...         4.642484
# 6                                                NaN         4.630768
# 7  Retrieve data as summaries from tables of a da...         4.615234
# 8  Identify and mitigate privacy and ethical risk...         4.613895
# 9  Import large tabular datasets & customize the ...         4.608734

# %%
user_history
# Out:
#                            CourseID  \
# 0  6c2645897c4a44b085d06823d2677cd4
# 1  6b87728edabc4c60b21e9d69993853a3
# 2  8accb9fef2b64091994e9e45e06fae48
# 3  0ffa7510c19f473281b9f3cddcbd93d1
# 4  0c7a2ffbfb4a426c825ab3d419ad6182
#
#                                          CourseName  ReviewNumber  AvgStar  \
# 0    Generative AI: Foundation Models and Platforms            62      4.8
# 1          Managing, Describing, and Analyzing Data            27      4.6
# 2                                      Using ggplot             0      0.0
# 3  Data Wrangling, Analysis and AB Testing with SQL           927      3.3
# 4                        AI for Good Specialization           205      4.8
#
#                 Level                             Unit  \
# 0      Beginner level                              IBM
# 1      Beginner level   University of Colorado Boulder
# 2      Beginner level         Coursera Project Network
# 3  Intermediate level  University of California, Davis
# 4      Beginner level                  DeepLearning.AI
#
#                                              Results  RatingStar
# 0  Describe the fundamental concepts of generativ...           5
# 1  Calculate descriptive statistics and create gr...           1
# 2  Install ggplot2\nLoad Tidyverse\nReview RStudi...           4
# 3  Validate and clean a dataset\nAssess and creat...           5
# 4  Master a step-by-step framework for the develo...           2
