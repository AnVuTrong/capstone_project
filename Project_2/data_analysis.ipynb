# %% [markdown]
# In this notebook, we will do data analysis on the data we have been issued.
# We will look at the data and try to understand it better, try to find some insights from the data.
# Process:
# - Load the data
# - Exploratory Data Analysis
# - Data Visualization

# %%
from modules.data_analysis import DataAnalysisCoursera

# %%
da = DataAnalysisCoursera(
    path_courses='data/courses.csv', 
    path_reviews='data/reviews.csv',
    save_path='img/'
)
df_courses, df_reviews = da.load_data()
da.eda()
# Out:
# Courses Data Analysis
# ...
# Head:
#                            CourseID  \
# 0  ba4c3f6733994eca9f6ce1f1926f9505
# 1  b6247bd0233443ba80cd67788ead9baa
# 2  04d627bdde99423ca09b2521631bf688
# 3  da0eb131c4064bddbae05fb64df425b8
# 4  e019840aa27444349b7019d25a1b1b8f
#
#                                           CourseName  \
# 0          IBM Data Science Professional Certificate
# 1                              What is Data Science?
# 2                             Data Science Challenge
# 3  Leverage Data Science for a More Agile Supply ...
# 4  Go Beyond the Numbers: Translate Data into Ins...
#
#                                Unit  ReviewNumber  AvgStar  \
# 0                               IBM         69587      4.6
# 1                               IBM         68152      4.7
# 2          Coursera Project Network             0      0.0
# 3  University of California, Irvine           184      4.5
# 4                            Google           481      4.8
#
# ...

# %% [markdown]
# ## COMMENTS:
# - The data is decently clean. There are no duplicate rows, but there are some missing values in the data. In the courses data, missing values are in the columns 'level' and 'results' while in the reviews data, there are missing values in the columns 'ReviewContent' and 'CourseID'.
# - We don't have to worry about the missing values as some courses might not specify the level or the results of the course, and some reviews do not require a review content.

# %%
da.data_visualize()

# %% [markdown]
# ## COMMENTS:
# - The data is from 2016 to 2024. Most of the courses' average rating is around 4.5 with a dip in 2016.
# - Top 10 courses with most reviews suggest the support on the theory that people tend to take interest in trending technologies of Data Science such as Data Analysis, Machine Learning and Deep Learning.
