# %%
from modules.data_preprocessing import DataPreprocessing
from modules.data_analysis import DataAnalysis

# %%
data_preprocessing = DataPreprocessing(
	data_path_1='data/1_Restaurants.csv',
	data_path_2='data/2_Reviews.csv',
	preprocessed_data_path = 'data/preprocessed_data.csv',
	ready_data_path = 'data/ready_data.csv',
)

# %%
df = data_preprocessing.preprocess_data_shopee_food()

# %%
df
# Out:
#           ID           User           ReviewTime  Rating  \
# 0          1        PHAN LE  2023-12-20 21:13:00     5.2
# 1          2           Thúy  2023-09-25 15:43:00     5.0
# 2          3    Quyên Quyên  2023-06-24 11:11:00     5.0
# 3          4    Phương Thảo  2022-12-22 14:58:00     1.0
# 4          5   Quỳnh Nguyễn  2022-09-23 22:40:00     4.2
# ...      ...            ...                  ...     ...
# 28668  29955     Trannuhamy  2020-10-26 12:16:00     7.0
# 28669  29956         Phương  2021-06-01 15:34:00    10.0
# 28670  29957             Tú  2021-01-31 14:29:00     3.4
# 28671  29958  Hoàng Hậu Mai  2020-10-27 18:06:00     7.6
# 28672  29959      ThoA Thai  2021-10-19 16:27:00    10.0
#
#                                                  Comment  IDRestaurant  \
# 0               Gà chiên còn sống, rất tanh. Khủng khiép             1
# 1                                 Đã ăn qua rồi, ăn ok ạ             1
# 2                                        Đã thư rất ngon             1
# 3      Tệ .. mua mang về cho 1 gói tương ớt. Và xin t...             1
# 4      21h30...2 đứa nhỏ kêu đói, sau 1 hồi bình loạn...             1
# ...                                                  ...           ...
# 28668  Đặt quán bún thái này trong chương trình của c...          1595
# 28669  Bánh ngon, nóng.\nGiao hàng nhanh.\nGiá phải c...          1609
# 28670  Phục vụ quá tệ\nPizza xúc xích double phô mai ...          1609
# 28671  Đang thèm gà rán thì lướt trúng ngay combo gà ...          1609
# 28672  Đây là quán bún chả ngon nhất ở Sài Gòn mà mìn...          1612
#
#                                               Restaurant  \
# 0                      Gà Rán & Burger McDonald's Đa Kao
# 1                      Gà Rán & Burger McDonald's Đa Kao
# 2                      Gà Rán & Burger McDonald's Đa Kao
# 3                      Gà Rán & Burger McDonald's Đa Kao
# 4                      Gà Rán & Burger McDonald's Đa Kao
# ...                                                  ...
# 28668       Tiên Tiên - Bún Thái Cay - Tân Chánh Hiệp 16
# 28669  3 Râu - Gà Rán, Pizza & Trà Sữa - 107 Nguyễn V...
# 28670  3 Râu - Gà Rán, Pizza & Trà Sữa - 107 Nguyễn V...
# 28671  3 Râu - Gà Rán, Pizza & Trà Sữa - 107 Nguyễn V...
# 28672            Đàm Trang - Bún Chả - Tân Chánh Hiệp 10
#
#                                                  Address OpeningTime District  \
# 0               2 - 6 Bis Điện Biên Phủ, Quận 1, TP. HCM       00:00   Quận 1
# 1               2 - 6 Bis Điện Biên Phủ, Quận 1, TP. HCM       00:00   Quận 1
# 2               2 - 6 Bis Điện Biên Phủ, Quận 1, TP. HCM       00:00   Quận 1
# 3               2 - 6 Bis Điện Biên Phủ, Quận 1, TP. HCM       00:00   Quận 1
# 4               2 - 6 Bis Điện Biên Phủ, Quận 1, TP. HCM       00:00   Quận 1
# ...                                                  ...         ...      ...
# 28668  52/4A Tân Chánh Hiệp 16, P. Tân Chánh Hiệp (Đầ...       06:00  Quận 12
# 28669  107 Nguyễn Văn Quá, P. Đông Hưng Thuận, Quận 1...       09:00  Quận 12
# 28670  107 Nguyễn Văn Quá, P. Đông Hưng Thuận, Quận 1...       09:00  Quận 12
# 28671  107 Nguyễn Văn Quá, P. Đông Hưng Thuận, Quận 1...       09:00  Quận 12
# 28672  27 Tân Chánh Hiệp 10, P. Tân Chánh Hiệp, Quận ...         NaN  Quận 12
#
#        ReviewCount ClosingTime  MaxPrice  MinPrice
# 0              100       23:59  200000.0   50000.0
# 1              100       23:59  200000.0   50000.0
# 2              100       23:59  200000.0   50000.0
# 3              100       23:59  200000.0   50000.0
# 4              100       23:59  200000.0   50000.0
# ...            ...         ...       ...       ...
# 28668            1       23:30  200000.0   25000.0
# 28669            3       23:59  120000.0   12000.0
# 28670            3       23:59  120000.0   12000.0
# 28671            3       23:59  120000.0   12000.0
# 28672            1         NaN       0.0       0.0
#
# [28673 rows x 14 columns]

# %%
data_analysis = DataAnalysis(df)

# %%
data_analysis.run()
